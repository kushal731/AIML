# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as p

# %%
df=pd.read_csv(r"C:\Users\SPTINT-21\Desktop\Iris_PCA.csv")

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='str')
