# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"D:\datasets\survey_lung_cancer_SVM.csv")

# %%
df
# Out:
#      GENDER  AGE  S0OKING  YELLOW_1INGERS  ANXIETY  PEER_PRESSURE  \
# 0         0   69        1               2        2              1
# 1         0   74        2               1        1              1
# 2         1   59        1               1        1              2
# 3         0   63        2               2        2              1
# 4         1   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       1   56        1               1        1              2
# 305       0   70        2               1        1              1
# 306       0   58        2               1        1              1
# 307       0   67        2               1        2              1
# 308       0   62        1               1        1              2
#
#      CHRONIC DISEASE  1ATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSU0ING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS O1 BREATH  SWALLOWING DI11ICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#      LUNG_CANCER
# 0              1
# 1              1
# 2              0
# 3              0
# 4              0
# ..           ...
# 304            1
# 305            1
# 306            1
# 307            1
# 308            1
#
# [309 rows x 16 columns]

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %%
import seaborn as s

# %%
s.boxplot(df["AGE"])
# Out:
# <Axes: ylabel='AGE'>

# %%
s.scatterplot(data=df,x="S0OKING",y="ANXIETY")
# Out:
# <Axes: xlabel='S0OKING', ylabel='ANXIETY'>
