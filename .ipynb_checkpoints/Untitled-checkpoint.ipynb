# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\SPTINT-21\Downloads\Iris (1).csv")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.groupby('Species').mean().plot(kind='bar',rot=0)
# Out:
# <Axes: xlabel='Species'>

# %%
plt.hist(df['PetalLengthCm'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x=df['SepalLengthCm'],y=df['PetalLengthCm'])

# %%
import seaborn as s

# %%
plt.boxplot(x='SepalWidthCm',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x211bde5a490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x211bde5a710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x211bde5a350>],
#  'medians': [<matplotlib.lines.Line2D at 0x211bde5a990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x211bde5aad0>],
#  'means': []}

# %%
df['PetalLengthCm'].mean().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['PetalLengthCm'].mean().plot(kind='bar')
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
df.groupby("Species")['PetalLengthCm'].mean().plot(kind='bar',rot=0)
# Out:
# <Axes: xlabel='Species'>

# %%
plt.plot(df['PetalLengthCm'])

# %%
plt.scatter(x=df['SepalWidthCm'],y=df['PetalWidthCm'])

# %%
df.groupby("Species")['PetalWidthCm'].plot(kind='box')
# Out:
# Species
# Iris-setosa        Axes(0.125,0.11;0.775x0.77)
# Iris-versicolor    Axes(0.125,0.11;0.775x0.77)
# Iris-virginica     Axes(0.125,0.11;0.775x0.77)
# Name: PetalWidthCm, dtype: object

# %%
df['Species'].value_counts().plot(kind='pie')
# Out:
# <Axes: >
