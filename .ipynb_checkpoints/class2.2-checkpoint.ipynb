# %%
import numpy as np

# %%
import time as t

# %%
arr=np.arange(1_000_000)

# %%
t1=t.time()
loop_res=[i*2 for i in arr]
t2=t.time()
t3=t.time()
vcc_res=arr*2
t4=t.time()
print("loop:",t2-t1)
print("vector:",t4-t3)
# Out:
# loop: 0.12533187866210938
# vector: 0.0038483142852783203

# %%
arr.mean()
# Out:
# np.float64(499999.5)

# %%
np.median(arr)
# Out:
# np.float64(499999.5)
