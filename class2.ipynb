# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5,6,7])

# %%
print(arr)
# Out:
# [1 2 3 4 5 6 7]

# %%
arr2=np.array([[1,2,3],[4,5,6]])
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2.sum()
# Out:
# np.int64(21)

# %%
arr2.min()
# Out:
# np.int64(1)

# %%
arr2.max()
# Out:
# np.int64(6)

# %%
print(np.sum(arr2, axis=0))
# Out:
# [5 7 9]

# %%
print(np.min(arr2, axis=1))
# Out:
# [1 4]

# %%
print(np.max(arr2, axis=1))
# Out:
# [3 6]

# %%
arr2+1
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
arr2-1
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr2*2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
arr2**2
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])

# %%
arr2/2
# Out:
# array([[0.5, 1. , 1.5],
#        [2. , 2.5, 3. ]])

# %%
arr3=np.array([[9,8,-7],[9,3,8]])
print(arr3)
# Out:
# [[ 9  8 -7]
#  [ 9  3  8]]

# %%
print(arr2+arr3)
# Out:
# [[10 10 -4]
#  [13  8 14]]

# %%
print(arr2-arr3)
# Out:
# [[-8 -6 10]
#  [-5  2 -2]]
